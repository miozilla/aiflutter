# %%
# !gcloud storage cp gs://cloud-training/OCBL453/photo-discovery/ag-web/ag_setup_re.ipynb .
# Out:
# Copying gs://cloud-training/OCBL453/photo-discovery/ag-web/ag_setup_re.ipynb to file://./ag_setup_re.ipynb
#   Completed files 1/1 | 13.3kiB/13.3kiB
